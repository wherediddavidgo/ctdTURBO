# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# import csv
# import datetime

# %%
# %reload_ext autoreload
# %autoreload 2

DATA_DIRECTORY="C:/Users/David/OneDrive/UNC/honors thesis/ctdTURBO_data"
DATA_FILE_PATH=f"{DATA_DIRECTORY}/tests/20230705_1.csv"

# %%
data: pd.DataFrame = pd.read_csv(DATA_FILE_PATH, skiprows=1)

data['Time'] = pd.to_datetime(data['Time'])
data.rename(columns = {'Time':'DateTime'}, inplace = True)

data['Mean T'] = (data['Temp A'] + data['Temp B'] + data['Temp C']) / 3
 
# data["dt"] = pd.to_datetime(f"{data['Date']} {data['Time']}")

# %%
fig, ax = plt.subplots()
# ax.scatter(data["DateTime"], data["Mean T"])
# ax.scatter(data["DateTime"], data["Conductivity"])
ax.scatter(data["DateTime"], data["Pressure"])
# ax.scatter(data["DateTime"], data["Proximity"])
# ax.scatter(data["DateTime"], data["Ambient"])
# ax.scatter(data["DateTime"], data["DO"])

plt.legend(["Pressure"])
